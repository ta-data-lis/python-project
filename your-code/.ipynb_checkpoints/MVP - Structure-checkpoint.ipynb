# %%
# define rooms and items


import random




sol_a = {'solution':'fire',
         'tip': ["hot", "it burns"]
}

sol_b = {'solution':'footsteps',
         'tip': ["feet", "walking","foot + something"]
}

sol_c = {'solution': '3',
         'tip': ["just do it!", "do the math","it's 3"]
    
}

sol_d = {'solution':'stamp',
         'tip': ["You use it for comunication", "mail", "it's in a postcard"]
}

sol_e = {'solution':'bottle',
         'tip': ["Used to store", "You can drink from it", "'something'of wine"]
}

sol_f = {'solution': 'promise',
         'tip': ["something you usualy say to your loved ones", "I '' that I will love you" ,"I 'something' I will quit smoking"]
    
}



_ridles = {'Feed me and I live, yet give me a drink and I die': sol_a, 
           'The more you take, the more you leave behind. What am I?': sol_b, '1 + 2': sol_c , 
           'What can travel around the world while staying in a corner?': sol_d,
           'What has a neck but no head?': sol_e,
           'What gets broken without being held?': sol_f
          
          }

### function for ridles

def ridles():


    ridle, solution = random.choice(list(_ridles.items()))

        
    answer = input(ridle + '\n\n' + 'what is the answer to this riddle?').strip().lower()
    print('')
    _tip_numb = 0
    while answer != solution['solution']:
        print('')
        _help = input("It's not right! Do you need help: Enter 'yes' or 'no'").strip().lower()
        if _help == 'yes':
            if _tip_numb < (len(solution['tip'])):
                print('')
                print(solution['tip'][_tip_numb])
                print('')
                _tip_numb += 1
            else:
                print('')
                print('You Have no more tips, your tips are :' + ' and '.join(solution['tip']))
                print('')
                answer = input(ridle + '\n' + 'what is the answer to this riddle?').strip().lower()
                print('')
        elif _help == 'no':
            print('')
            answer = input(ridle + '\n' + 'what is the answer to this riddle?').strip().lower()
    else:
        if ridle in _ridles.keys() and len(_ridles.keys()) > 0:
            _ridles.pop(ridle)
            print('')
            print('You solution is correct!')
            print('')
        else:
            print('')
            print('There is no more riddles')
            print('')


        


couch = {
    "name": "couch",
    "type": "furniture",
}

#all doors 

door_a = {
    "name": "door a",
    "type": "door",
}

door_b = {
    "name": "door b",
    "type": "door",
}

door_c = {
    "name": "door c",
    "type": "door",
}

door_d = {
    "name": "door d",
    "type": "door",
}


key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

##Keys

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

## objects

piano = {
    "name": "piano",
    "type": "furniture",
}

queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

dresser_ = {
    "name": "dresser",
    "type": "furniture",
}

dining_table = {
    "name": "dining table",
    "type": "dining table",
}

## ROOMS
game_room = {
    "name": "game room",
    "type": "room",
}



bedroom_1 ={
    "name": "bedroom 1",  #test
    "type": "room",
}

bedroom_2 ={
    "name": "bedroom2",  #test
    "type": "room",
}

living_room ={
    "name": "living room",  #test
    "type": "room",
}

outside = {
  "name": "outside"
}


#all_rooms = [game_room, bedroom_1, bedroom_2, living_room, outside]

#all_doors = [door_a, door_b, door_c, door_d ]

#all_keys = [key_a, key_b, key_c, key_d]

# define which items/rooms are related

#object_relations = {
#    "game room": [couch, piano, door_a],
#    "piano": [key_a],
#    "outside": [door_a],
#    "door a": [game_room, outside] # change outside to bedroom_1
#}

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "bedroom 1": [queen_bed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "bedroom2": [double_bed, dresser_, door_b],
    "double bed": [key_c],
    "dresser":[key_d],
    "living room": [dining_table, door_c, door_d],
    "dining table":[],##
    "outside": [door_d],
    "door a": [game_room, bedroom_1],
    "door b": [bedroom_2, bedroom_1],
    "door c": [bedroom_1, living_room],
    "door d": [living_room, outside],
}




# define game state. Do not directly change this dict. 
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This 
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
def linebreak():
    """
    Print a line break
    """
    print("\n\n")

def start_game():
    """
    Start the game
    """
    print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
    play_room(game_state["current_room"])

def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either 
    explore (list all items in this room) or examine an item found here.
    """
    game_state["current_room"] = room
    if(game_state["current_room"] == game_state["target_room"]):
        print("Congrats! You escaped the room!")
    #elif()
    else:
        print("")
        print("You are now in " + room["name"])
        print("")
        intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip().lower()
        print("")
        if intended_action == "explore":
            explore_room(room)
            play_room(room)
        elif intended_action == "examine":
            examine_item(input("What would you like to examine?").strip().lower())
            print("")
        else:
            print("Not sure what you mean. Type 'explore' or 'examine'.")
            print("")
            play_room(room)
        linebreak()

def explore_room(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [i["name"] for i in object_relations[room["name"]]]
    print("You explore the room. This is " + room["name"] + ". You find " + ", ".join(items))

def get_next_room_of_door(door, current_room): # THIS ONE MAKES THE CHANGE IN ROOM (THE FIRST VARIABLE WHO MAKES THE CODE RUN)
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room. 
    """
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):  ##Loop all the elemet in the object relation key = door a or door b ....
            return room
#THE DOOR INPUT VARIABLE OF THE FUNCTION CAMES FROM, EXAMINE_ITEM
        

    
def examine_item(item_name):
    """
    Examine an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been 
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    current_room = game_state["current_room"]
    next_room = ""
    output = None
    
    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            print("")
            output = "You examine " + item_name + ". "
            print("")
            if(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key):
                    print("")
                    output += "You unlock it with a key you have."
                    print("")
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    print("")
                    output += "It is locked but you don't have the key."
            else:
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0): ## This goes to the object relation and removes in the item explored the item in it
                    print('')
                    print("In order to get the object you need solve this riddle!")
                    print('')
                    ridles() ###
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    output += "You find " + item_found["name"] + "."
                else:
                    output += "There isn't anything interesting about it."
                    print("")
            print(output)
            break

    if(output is None):
        print("")
        print("The item you requested is not found in the current room.")
        print("")
    if(next_room and input("\n Do you want to go to the next room? Enter 'yes' or 'no'").strip().lower() == 'yes'):
        print("")
        play_room(next_room)
    else:
        play_room(current_room)

# %%
game_state = INIT_GAME_STATE.copy() #DON'T UNDERSTAND WHAY WE NEED TO SAVE THE DICTIONARY IN ANOTHER VARIABLE #IS IT IN ORDER FOR US TO RUN THE GAME MORE THAN ONE TIME. SO THAT THE INIT_GAME_STATE DIC DONT BE CHANGED AND RESETS THE GAME FROM THE START?

start_game()

#print(game_state)
#print(INIT_GAME_STATE)
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
#
# You are now in game room
#
# What would you like to do? Type 'explore' or 'examine'?examine
#
# What would you like to examine?piano
#
#
#
# In order to get the object you need solve this riddle!
#
# 1 + 2
#
# what is the answer to this riddle?3
#
#
# You solution is correct!
#
# You examine piano. You find key for door a.
#
# You are now in game room
#
# What would you like to do? Type 'explore' or 'examine'?explore
#
# You explore the room. This is game room. You find couch, piano, door a
#
# You are now in game room
#
# What would you like to do? Type 'explore' or 'examine'?examine
#
# What would you like to examine?door a
#
#
#
#
# You examine door a. You unlock it with a key you have.
#
#  Do you want to go to the next room? Enter 'yes' or 'no'yes
#
#
# You are now in bedroom 1
#
# What would you like to do? Type 'explore' or 'examine'?examine
#
# What would you like to examine?queen bed
#
#
#
# In order to get the object you need solve this riddle!
#
# What can travel around the world while staying in a corner?
#
# what is the answer to this riddle?ee
#
#
# It's not right! Do you need help: Enter 'yes' or 'no'yes
#
# You use it for comunication
#
#
# It's not right! Do you need help: Enter 'yes' or 'no'ss
#
# It's not right! Do you need help: Enter 'yes' or 'no'yes
#
# mail
#
#
# It's not right! Do you need help: Enter 'yes' or 'no'ss
#
# It's not right! Do you need help: Enter 'yes' or 'no'yes
#
# it's in a postcard
#
#
# It's not right! Do you need help: Enter 'yes' or 'no'ss
#
# It's not right! Do you need help: Enter 'yes' or 'no'yes
#
# You Have no more tips, your tips are :You use it for comunication and mail and it's in a postcard
#
# What can travel around the world while staying in a corner?
# what is the answer to this riddle?ss
#
# It's not right! Do you need help: Enter 'yes' or 'no'yes
#
# You Have no more tips, your tips are :You use it for comunication and mail and it's in a postcard
#
# What can travel around the world while staying in a corner?
# what is the answer to this riddle?stamp
#
# You solution is correct!
#
# You examine queen bed. You find key for door b.
#
# You are now in bedroom 1
#
# What would you like to do? Type 'explore' or 'examine'?examine
#
# What would you like to examine?door c
#
#
#
# You examine door c. It is locked but you don't have the key.
#
# You are now in bedroom 1
#
# What would you like to do? Type 'explore' or 'examine'?examine
#
# What would you like to examine?door c
#
#
#
# You examine door c. It is locked but you don't have the key.
#
# You are now in bedroom 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4f082f52c0a2> in <module>
#       1 game_state = INIT_GAME_STATE.copy() #DON'T UNDERSTAND WHAY WE NEED TO SAVE THE DICTIONARY IN ANOTHER VARIABLE #IS IT IN ORDER FOR US TO RUN THE GAME MORE THAN ONE TIME. SO THAT THE INIT_GAME_STATE DIC DONT BE CHANGED AND RESETS THE GAME FROM THE START?
#       2
# ----> 3 start_game()
#       4
#       5 #print(game_state)
#
# <ipython-input-4-c63befda339c> in start_game()
#      10     """
#      11     print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 12     play_room(game_state["current_room"])
#      13
#      14 def play_room(room):
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      32             play_room(room)
#      33         elif intended_action == "examine":
# ---> 34             examine_item(input("What would you like to examine?").strip().lower())
#      35             print("")
#      36         else:
#
# <ipython-input-4-c63befda339c> in examine_item(item_name)
#     116         play_room(next_room)
#     117     else:
# --> 118         play_room(current_room)
#     119
#     120
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      30         if intended_action == "explore":
#      31             explore_room(room)
# ---> 32             play_room(room)
#      33         elif intended_action == "examine":
#      34             examine_item(input("What would you like to examine?").strip().lower())
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      32             play_room(room)
#      33         elif intended_action == "examine":
# ---> 34             examine_item(input("What would you like to examine?").strip().lower())
#      35             print("")
#      36         else:
#
# <ipython-input-4-c63befda339c> in examine_item(item_name)
#     114     if(next_room and input("\n Do you want to go to the next room? Enter 'yes' or 'no'").strip().lower() == 'yes'):
#     115         print("")
# --> 116         play_room(next_room)
#     117     else:
#     118         play_room(current_room)
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      32             play_room(room)
#      33         elif intended_action == "examine":
# ---> 34             examine_item(input("What would you like to examine?").strip().lower())
#      35             print("")
#      36         else:
#
# <ipython-input-4-c63befda339c> in examine_item(item_name)
#     116         play_room(next_room)
#     117     else:
# --> 118         play_room(current_room)
#     119
#     120
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      32             play_room(room)
#      33         elif intended_action == "examine":
# ---> 34             examine_item(input("What would you like to examine?").strip().lower())
#      35             print("")
#      36         else:
#
# <ipython-input-4-c63befda339c> in examine_item(item_name)
#     116         play_room(next_room)
#     117     else:
# --> 118         play_room(current_room)
#     119
#     120
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      32             play_room(room)
#      33         elif intended_action == "examine":
# ---> 34             examine_item(input("What would you like to examine?").strip().lower())
#      35             print("")
#      36         else:
#
# <ipython-input-4-c63befda339c> in examine_item(item_name)
#     116         play_room(next_room)
#     117     else:
# --> 118         play_room(current_room)
#     119
#     120
#
# <ipython-input-4-c63befda339c> in play_room(room)
#      26         print("You are now in " + room["name"])
#      27         print("")
# ---> 28         intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip().lower()
#      29         print("")
#      30         if intended_action == "explore":
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# /usr/local/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
import random


sol_a = {'solution':'fire',
         'tip': ["something hot", "it burns"]
}

sol_b = {'solution':'footsteps',
         'tip': ["feet", "walking"]
}

sol_c = {'solution': '3',
         'tip': ["just do it!", "it's 3"]
    
}


print(len(sol_c['tip']))

_ridles = {'Feed me and I live, yet give me a drink and I die': sol_a, 'The more you take, the more you leave behind. What am I?': sol_b, '1 + 2': sol_c }
#print(_ridles.keys())

def ridles():


    ridle, solution = random.choice(list(_ridles.items()))


    answer = input(ridle + '\n\n' + 'what is the answer to this riddle?').strip().lower()
    _tip_numb = 0
    while answer != solution['solution']:
        _help = input("It's not right! Do you need help: Enter 'yes' or 'no'").strip().lower()
        if _help == 'yes':
            if _tip_numb < (len(solution['tip'])):
                print(solution['tip'][_tip_numb])
                _tip_numb += 1
            else:
                print('You Have no more tips, your tips are :' + ' and '.join(solution['tip']))
            answer = input(ridle + '\n' + 'what is the answer to this riddle?').strip().lower()
        elif _help == 'no':
            answer = input(ridle + '\n' + 'what is the answer to this riddle?').strip().lower()
    else:
        if ridle in _ridles.keys() and len(_ridles.keys()) > 0:
            _ridles.pop(ridle)
            print('You solution is correct!')
        else:
            print('There is no more riddles')

ridles()

# %%
print(_ridles)

# %%
# to add a sound!!!

"""from playsound import pl


pl('/Users/Shiva/Documents/DATA_ANALYTICS/Week1/project/python-project/Tram-bell-sound-effect.mp3')"""

# %%
### se nao desidires nao continuar game over!!!
